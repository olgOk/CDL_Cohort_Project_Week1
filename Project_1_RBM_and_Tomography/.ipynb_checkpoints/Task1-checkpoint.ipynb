# %% [markdown]
# # Task #1
#
# A template code for training an RBM on H$_2$ data for $r = 1.2$ is shown here. Modify this!
#
# Imports and loading in data:

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import os
from RBM_helper import RBM
import H2_energy_calculator
import typing
import collections

# training_data = torch.from_numpy(np.loadtxt("H2_data/R_1.2_samples.txt"))
training_data = torch.from_numpy(np.loadtxt("H2_data/R_1.2_samples.txt"))
coeff = np.loadtxt("H2_data/H2_coefficients.txt")[20,:]

true_energy = H2_energy_calculator.energy_from_freq(training_data, coeff)
print("H2 energy for r = 1.2: ",true_energy)
# Out:
# H2 energy for r = 1.2:  -1.0642022250418146

# %% [markdown]
# Define the RBM:

# %%
n_vis = 2
n_hin = 10

rbm = RBM(n_vis, n_hin)

# %% [markdown]
# Train the RBM:

# %%
def train_RBM(training_data:torch.Tensor) ->float:
    """
        Train Restricted Bolzman Machiene.
        Args:
            training_data: A tensor of binary data of radius.
        Returns:
            Energy value.
        
    """
    
    epochs = 500 # number of training steps
    num_samples = 1000 # number of samples to generate from the RBM to calculate the H2 energy

    true_energy = H2_energy_calculator.energy_from_freq(training_data, coeff)
    print("True energy: ",true_energy)

    for e in range(1, epochs+1):
        # do one epoch of training
        rbm.train(training_data)   

        # now generate samples and calculate the energy
        if e % 100 == 0:
#             print("\nEpoch: ", e)
#             print("Sampling the RBM...")

            # For sampling the RBM, we need to do Gibbs sampling.
            # Initialize the Gibbs sampling chain with init_state as defined below.
            init_state = torch.zeros(num_samples, n_vis)
            RBM_samples = rbm.draw_samples(15, init_state)

#             print("Done sampling. Calculating energy...")       

            energies = H2_energy_calculator.energy(RBM_samples, coeff, rbm.wavefunction) 
            print("Energy from RBM samples: ", energies.item())
    return energies.item()

# %%
# 
# load R_<r_value_samples.txt from H2_data folder
# 
# evaluate true_energy on each training data, use it to plot E_bond(r)

Ebond = {}
directory = 'H2_data'
for entry in os.scandir(directory):
    if (entry.path.endswith("samples.txt")):
        training_data = torch.from_numpy(np.loadtxt(entry))
        radius = entry.name.split("_")[1]
        Ebond[radius] = train_RBM(training_data)
#         print(Ebond)
# Out:
# True energy:  -1.0497107493775149
# Energy from RBM samples:  -0.9765411168327314
# Energy from RBM samples:  -0.9818929464021235
# Energy from RBM samples:  -0.9715162870271281
# Energy from RBM samples:  -0.9763157804072058
# Energy from RBM samples:  -0.9817204616585951
# True energy:  -1.0324782127249015
# Energy from RBM samples:  -1.3563130595854553
# Energy from RBM samples:  -1.4466457270540296
# Energy from RBM samples:  -1.3885099956586613
# Energy from RBM samples:  -1.4982056896305016
# Energy from RBM samples:  -1.4564876014895576
# True energy:  -1.0362617443402724
# Energy from RBM samples:  -1.436311554577149
# Energy from RBM samples:  -1.4338545233333848
# Energy from RBM samples:  -1.4507324829922148
# Energy from RBM samples:  -1.4720569208653664
# Energy from RBM samples:  -1.4513918115593802
# True energy:  -0.9724744744994698
# Energy from RBM samples:  -0.8597369690493385
# Energy from RBM samples:  -0.8671392655634197
# Energy from RBM samples:  -0.8661266408281032
# Energy from RBM samples:  -0.8736405468032621
# Energy from RBM samples:  -0.8680156347094095
# True energy:  -1.0272612255781348
# Energy from RBM samples:  -1.2468758979012868
# Energy from RBM samples:  -1.3984477390210381
# Energy from RBM samples:  -1.4917872221057658
# Energy from RBM samples:  -1.5589796511013718
# Energy from RBM samples:  -1.7222787968349533
# True energy:  -1.0638310134297058
# Energy from RBM samples:  -1.0908153331104251
# Energy from RBM samples:  -1.0567376632352403
# Energy from RBM samples:  -1.0443441736778558
# Energy from RBM samples:  -1.0430471703208604
# Energy from RBM samples:  -1.050786624001394
# True energy:  -1.045890709404601
# Energy from RBM samples:  -0.9647609618275124
# Energy from RBM samples:  -0.9402437456682003
# Energy from RBM samples:  -0.9477722139826921
# Energy from RBM samples:  -0.9434052022977737
# Energy from RBM samples:  -0.9393422780876208
# True energy:  -1.0392850239621994
# Energy from RBM samples:  -1.1627317557353147
# Energy from RBM samples:  -1.2505592725735446
# Energy from RBM samples:  -1.3617580809038594
# Energy from RBM samples:  -1.4098912557400554
# Energy from RBM samples:  -1.4446266567378292
# True energy:  -1.046658951711928
# Energy from RBM samples:  -1.4194844947109944
# Energy from RBM samples:  -1.4434009443736044
# Energy from RBM samples:  -1.4212082174624552
# Energy from RBM samples:  -1.426240886093535
# Energy from RBM samples:  -1.410552424123688
# True energy:  -1.0285713264808696
# Energy from RBM samples:  -1.4780661310386631
# Energy from RBM samples:  -1.5301096713091926
# Energy from RBM samples:  -1.6348253196026046
# Energy from RBM samples:  -1.6149185347614146
# Energy from RBM samples:  -1.6463784597780207
# True energy:  -0.9901309142199367
# Energy from RBM samples:  -0.9004222905711092
# Energy from RBM samples:  -0.8816436649096246
# Energy from RBM samples:  -0.8681717635821006
# Energy from RBM samples:  -0.869848862741892
# Energy from RBM samples:  -0.8556112577898969
# True energy:  -0.8706320496450434
# Energy from RBM samples:  -0.8040690785095438
# Energy from RBM samples:  -0.8088741935639617
# Energy from RBM samples:  -0.8070764260424292
# Energy from RBM samples:  -0.8041135532863151
# Energy from RBM samples:  -0.806824997395278
# True energy:  -1.0550336434246872
# Energy from RBM samples:  -0.9256620623479506
# Energy from RBM samples:  -0.946692045522809
# Energy from RBM samples:  -0.9570308049906573
# Energy from RBM samples:  -0.9758856743663886
# Energy from RBM samples:  -0.9635893884006337
# True energy:  -1.0609448171032052
# Energy from RBM samples:  -0.9879922028350443
# Energy from RBM samples:  -1.0017177441318554
# Energy from RBM samples:  -1.0052056615913973
# Energy from RBM samples:  -1.0049399511073682
# Energy from RBM samples:  -0.9993137554714869
# True energy:  -0.9006480965108701
# Energy from RBM samples:  -0.8556414775600545
# Energy from RBM samples:  -0.8239363667330285
# Energy from RBM samples:  -0.8025464888518955
# Energy from RBM samples:  -0.8308853295199476
# Energy from RBM samples:  -0.8266573617673578
# True energy:  -1.0597637205756967
# Energy from RBM samples:  -0.9404300210744552
# Energy from RBM samples:  -1.0128994120486454
# Energy from RBM samples:  -1.0678506232229499
# Energy from RBM samples:  -1.1070178906811652
# Energy from RBM samples:  -1.1282449877280392
# True energy:  -1.062763861747277
# Energy from RBM samples:  -1.0869156544506577
# Energy from RBM samples:  -1.0675779300250567
# Energy from RBM samples:  -1.047590486992989
# Energy from RBM samples:  -1.0371688113833377
# Energy from RBM samples:  -1.0284537615952327
# True energy:  -0.8874596507187792
# Energy from RBM samples:  -0.8547968443462084
# Energy from RBM samples:  -0.8197282905655867
# Energy from RBM samples:  -0.8204784356877183
# Energy from RBM samples:  -0.8150494932928762
# Energy from RBM samples:  -0.8125304563329154
# True energy:  -0.9798311216602571
# Energy from RBM samples:  -0.8415958925864088
# Energy from RBM samples:  -0.839042720719481
# Energy from RBM samples:  -0.8513747785111168
# Energy from RBM samples:  -0.8492420004860979
# Energy from RBM samples:  -0.8696999599057336
# True energy:  -0.9281284249929258
# Energy from RBM samples:  -0.8519643827677141
# Energy from RBM samples:  -0.8325369450463541
# Energy from RBM samples:  -0.8378573938360171
# Energy from RBM samples:  -0.8284184249122675
# Energy from RBM samples:  -0.804949535281867
# True energy:  -0.8865891713144782
# Energy from RBM samples:  -0.7982162499208963
# Energy from RBM samples:  -0.8365126130972692
# Energy from RBM samples:  -0.8057342117224009
# Energy from RBM samples:  -0.8203653901813932
# Energy from RBM samples:  -0.8172567271664095
# True energy:  -1.0537947736069744
# Energy from RBM samples:  -0.8868256251850519
# Energy from RBM samples:  -0.9561473432478493
# Energy from RBM samples:  -1.0038859365069026
# Energy from RBM samples:  -1.0495388399450374
# Energy from RBM samples:  -1.0839206851374024
# True energy:  -1.0339439695134862
# Energy from RBM samples:  -1.1360070821663926
# Energy from RBM samples:  -1.177470694233504
# Energy from RBM samples:  -1.2190920063696589
# Energy from RBM samples:  -1.2527421517965047
# Energy from RBM samples:  -1.2868667740743691
# True energy:  -0.9988361402323337
# Energy from RBM samples:  -1.033477029298568
# Energy from RBM samples:  -0.9525400279633063
# Energy from RBM samples:  -0.9025540421048281
# Energy from RBM samples:  -0.8865102252993313
# Energy from RBM samples:  -0.8822742413591065
# True energy:  -0.9247568227883267
# Energy from RBM samples:  -0.8508929436976871
# Energy from RBM samples:  -0.840491476304219
# Energy from RBM samples:  -0.8388265989758131
# Energy from RBM samples:  -0.8192130644422307
# Energy from RBM samples:  -0.8093277129759364
# True energy:  -1.05858094757703
# Energy from RBM samples:  -0.8999862673223928
# Energy from RBM samples:  -0.9348940458570588
# Energy from RBM samples:  -0.976989623336697
# Energy from RBM samples:  -1.0165996497612255
# Energy from RBM samples:  -1.0477916088893986
# True energy:  -1.0408339191583378
# Energy from RBM samples:  -1.0034864631064955
# Energy from RBM samples:  -0.9730175614967991
# Energy from RBM samples:  -0.9535923866670959
# Energy from RBM samples:  -0.9382657770308981
# Energy from RBM samples:  -0.9238739076823332
# True energy:  -1.0531258395865126
# Energy from RBM samples:  -0.9850597576730342
# Energy from RBM samples:  -1.0218726785631855
# Energy from RBM samples:  -1.0540302264062906
# Energy from RBM samples:  -1.090256448275151
# Energy from RBM samples:  -1.1257952426861804
# True energy:  -0.9078290367824813
# Energy from RBM samples:  -0.9457425396580476
# Energy from RBM samples:  -0.881240250716519
# Energy from RBM samples:  -0.8621245366558304
# Energy from RBM samples:  -0.8418956406099061
# Energy from RBM samples:  -0.8229219267008054
# True energy:  -0.912841216005112
# Energy from RBM samples:  -0.8161361062768803
# Energy from RBM samples:  -0.8100385648243933
# Energy from RBM samples:  -0.8098515465130167
# Energy from RBM samples:  -0.8220212813532541
# Energy from RBM samples:  -0.810018181011853
# True energy:  -0.9161563118436927
# Energy from RBM samples:  -0.8117694041326812
# Energy from RBM samples:  -0.8209598985104662
# Energy from RBM samples:  -0.8126428200510915
# Energy from RBM samples:  -0.8034056195558027
# Energy from RBM samples:  -0.8251541470562305
# True energy:  -1.0628704803822298
# Energy from RBM samples:  -0.8867544337080102
# Energy from RBM samples:  -0.891646017407749
# Energy from RBM samples:  -0.9263313426778746
# Energy from RBM samples:  -0.9734168402844343
# Energy from RBM samples:  -0.9904293825002182
# True energy:  -1.0101180286069797
# Energy from RBM samples:  -0.9651799173240794
# Energy from RBM samples:  -0.9214794600744666
# Energy from RBM samples:  -0.9034066434585997
# Energy from RBM samples:  -0.9039254651842801
# Energy from RBM samples:  -0.8903521086641538
# True energy:  -0.9453367978774545
# Energy from RBM samples:  -0.8628864714174717
# Energy from RBM samples:  -0.8511784467346852
# Energy from RBM samples:  -0.834625804758411
# Energy from RBM samples:  -0.8532025615500471
# Energy from RBM samples:  -0.83004779269682
# True energy:  -1.0430990090273842
# Energy from RBM samples:  -0.8818065235206183
# Energy from RBM samples:  -0.919563127307983
# Energy from RBM samples:  -0.9615078268038552
# Energy from RBM samples:  -0.9878414509713722
# Energy from RBM samples:  -1.0183648575519064
# True energy:  -0.8764884896622689
# Energy from RBM samples:  -0.918059566809079
# Energy from RBM samples:  -0.8697377883130497
# Energy from RBM samples:  -0.8469874751385309
# Energy from RBM samples:  -0.8118543674328853
# Energy from RBM samples:  -0.8174157641873523
# True energy:  -0.8686928806257138
# Energy from RBM samples:  -0.8171865395522546
# Energy from RBM samples:  -0.814170918788056
# Energy from RBM samples:  -0.8369513466229649
# Energy from RBM samples:  -0.8067627273078629
# Energy from RBM samples:  -0.8147368410388628
# True energy:  -1.0289787152870253
# Energy from RBM samples:  -0.8669809692640639
# Energy from RBM samples:  -0.8858949377248685
# Energy from RBM samples:  -0.9219940215623953
# Energy from RBM samples:  -0.9651845521492031
# Energy from RBM samples:  -1.0009391566902428
# True energy:  -0.868169806585124
# Energy from RBM samples:  -0.895110488563297
# Energy from RBM samples:  -0.8549030529620342
# Energy from RBM samples:  -0.8351379286407418
# Energy from RBM samples:  -0.8209648369688926
# Energy from RBM samples:  -0.8006550445835002
# True energy:  -0.9707890932965086
# Energy from RBM samples:  -0.8324942492030598
# Energy from RBM samples:  -0.8409342848949827
# Energy from RBM samples:  -0.8340455044331491
# Energy from RBM samples:  -0.8292421610198212
# Energy from RBM samples:  -0.8290295739691397
# True energy:  -1.0585418149658092
# Energy from RBM samples:  -0.8623413794875624
# Energy from RBM samples:  -0.8861432231846029
# Energy from RBM samples:  -0.9023092284270047
# Energy from RBM samples:  -0.9158352118753375
# Energy from RBM samples:  -0.9203809453198217
# True energy:  -0.9590625522828007
# Energy from RBM samples:  -0.8907376882336162
# Energy from RBM samples:  -0.895888160741487
# Energy from RBM samples:  -0.8723098837678779
# Energy from RBM samples:  -0.852400357408519
# Energy from RBM samples:  -0.8568260289854375
# True energy:  -1.057236404388469
# Energy from RBM samples:  -0.8946206245034416
# Energy from RBM samples:  -0.9185077815613563
# Energy from RBM samples:  -0.949326261845324
# Energy from RBM samples:  -0.9587907294321062
# Energy from RBM samples:  -0.9931975420013992
# True energy:  -1.0494348817130146
# Energy from RBM samples:  -1.0110804501581012
# Energy from RBM samples:  -1.03909511926269
# Energy from RBM samples:  -1.0587106868321077
# Energy from RBM samples:  -1.077160265738177
# Energy from RBM samples:  -1.0996181758673786
# True energy:  -0.9397402628548327
# Energy from RBM samples:  -1.00086635706517
# Energy from RBM samples:  -0.9247650011105228
# Energy from RBM samples:  -0.9019153812158597
# Energy from RBM samples:  -0.8794599589743392
# Energy from RBM samples:  -0.8575229066623147
# True energy:  -1.0311415155381198
# Energy from RBM samples:  -0.8874529974987905
# Energy from RBM samples:  -0.8708965420551769
# Energy from RBM samples:  -0.8820144869863283
# Energy from RBM samples:  -0.8862616785708376
# Energy from RBM samples:  -0.8948246165282238
# True energy:  -1.0640336454496149
# Energy from RBM samples:  -0.9207651704398536
# Energy from RBM samples:  -0.9449117777712219
# Energy from RBM samples:  -0.9603555125063914
# Energy from RBM samples:  -0.9620839851482867
# Energy from RBM samples:  -0.977055974926964
# True energy:  -1.0326783769893295
# Energy from RBM samples:  -0.9532538930523525
# Energy from RBM samples:  -0.9541354300143219
# Energy from RBM samples:  -0.9386440574348858
# Energy from RBM samples:  -0.9404383378276374
# Energy from RBM samples:  -0.9210394985865243
# True energy:  -1.0380608769339534
# Energy from RBM samples:  -0.9541827966489437
# Energy from RBM samples:  -0.9786607266323798
# Energy from RBM samples:  -1.0012069147308766
# Energy from RBM samples:  -1.0213057107971508
# Energy from RBM samples:  -1.0407710536811896
# True energy:  -1.0452519125171207
# Energy from RBM samples:  -1.0598191615475903
# Energy from RBM samples:  -1.0768286245556118
# Energy from RBM samples:  -1.0959522091569984
# Energy from RBM samples:  -1.111944065727198
# Energy from RBM samples:  -1.1266451377398405
# True energy:  -1.0642022250418146
# Energy from RBM samples:  -1.1136597931218892
# Energy from RBM samples:  -1.114257308691768
# Energy from RBM samples:  -1.1132829340497983
# Energy from RBM samples:  -1.1060755711416907
# Energy from RBM samples:  -1.112070324529132
# True energy:  -1.0176683464200735
# Energy from RBM samples:  -1.050476814580996
# Energy from RBM samples:  -1.0066367730123342
# Energy from RBM samples:  -0.9847747489845645
# Energy from RBM samples:  -0.9589128373023037
# Energy from RBM samples:  -0.9353721540374706
# True energy:  -0.8762670756779187
# Energy from RBM samples:  -0.8898484486717939
# Energy from RBM samples:  -0.8590537635627017
# Energy from RBM samples:  -0.843932806720533
# Energy from RBM samples:  -0.8347651603743562
# Energy from RBM samples:  -0.81272893212242
# True energy:  -1.061627926407983
# Energy from RBM samples:  -0.840418235778114
# Energy from RBM samples:  -0.8728912789255089
# Energy from RBM samples:  -0.9037424673532253
# Energy from RBM samples:  -0.9198766305076291
# Energy from RBM samples:  -0.9352208434089566

# %%
Ebond_sorted = collections.OrderedDict(sorted(Ebond.items()))
x_values = [] # radii
y_values = [] # Energy

for key, val in Ebond_sorted.items():
    x_values.append(float(key))
    y_values.append(val)

# plot Ebont(r)
plt.plot(x_values, y_values)
plt.xlabel('r')
plt.ylabel('Ebond')
plt.title('Ebond(r)')
plt.show()
